# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
date_str = "2024.09.13"
time_str = "14.24.58"

cwd = os.getcwd() + f'\\SessionLogs\\{date_str}\\Athena\\{time_str}\\'


#path = cwd + 'SessionLogs/2024.08.25/Athena/20.23.32'
#path = Path.cwd() / 'data' / 'SessionLogs' / '2024.08.25' / 'Athena'  / '20.23.32'
df_motor = pd.read_csv(cwd + 'motor.csv')
df_imu = pd.read_csv(cwd + 'imu.csv')

# %%
df_acc = df_imu[df_imu['type'] == 'acceleration']
# Create the figure and the axes
plt.figure(figsize=(10, 6))

# Plotting the three different line graphs
plt.plot(df_acc['time'], df_acc['x'], label='x')
plt.plot(df_acc['time'], df_acc['y'], label='y')
plt.plot(df_acc['time'], df_acc['z'], label='z')

# Adding title and labels
plt.title('acceleration')
plt.xlabel('x')
plt.ylabel('y')

# Adding a legend
plt.legend()

# Show the plot
plt.show()

df_acc
# Out:
#            time          type  imutime  status         x         y         z  \
# 0      0.066129  acceleration  1491117       0  0.003906  0.001953  0.000000
# 5      0.188706  acceleration  1491261       0 -0.005859 -0.001953  0.001953
# 10     0.321687  acceleration  1491380       0 -0.001953  0.000000  0.001953
# 15     0.406199  acceleration  1491426       0  0.142578  0.009766 -0.009766
# 20     0.511901  acceleration  1491585       0  0.257812  0.005859  0.019531
# ...         ...           ...      ...     ...       ...       ...       ...
# 3795  87.942460  acceleration  1579059       0 -0.021484 -0.121094  0.113281
# 3800  88.052786  acceleration  1579161       0 -0.107422 -0.074219  0.083984
# 3805  88.162902  acceleration  1579274       0 -0.009766 -0.054688  0.148438
# 3810  88.298409  acceleration  1579398       0 -0.191406 -0.152344  0.132812
# 3815  88.377945  acceleration  1579438       0 -0.099609 -0.126953  0.185547
#
#      real
# 0     NaN
# 5     NaN
# 10    NaN
# 15    NaN
# 20    NaN
# ...   ...
# 3795  NaN
# 3800  NaN
# 3805  NaN
# 3810  NaN
# 3815  NaN
#
# [764 rows x 8 columns]

# %%
df_acc = df_imu[df_imu['type'] == 'gyroscope']
# Create the figure and the axes
plt.figure(figsize=(10, 6))

# Plotting the three different line graphs
plt.plot(df_acc['time'], df_acc['x'], label='x')
plt.plot(df_acc['time'], df_acc['y'], label='y')
plt.plot(df_acc['time'], df_acc['z'], label='z')

# Adding title and labels
plt.title('gyroscope')
plt.xlabel('x')
plt.ylabel('y')

# Adding a legend
plt.legend()

# Show the plot
plt.show()

# %%
df_acc = df_imu[df_imu['type'] == 'magnetic']
# Create the figure and the axes
plt.figure(figsize=(10, 6))

# Plotting the three different line graphs
plt.plot(df_acc['time'], df_acc['x'], label='x')
plt.plot(df_acc['time'], df_acc['y'], label='y')
plt.plot(df_acc['time'], df_acc['z'], label='z')

# Adding title and labels
plt.title('magnetic')
plt.xlabel('x')
plt.ylabel('y')

# Adding a legend
plt.legend()

# Show the plot
plt.show()

# %%
# Create the figure and the axes
plt.figure(figsize=(10, 6))

# Plotting the three different line graphs
plt.plot(df_acc['time'], df_acc['x'], label='x')
plt.plot(df_acc['time'], df_acc['y'], label='y')
plt.plot(df_acc['time'], df_acc['z'], label='z')
plt.plot(df_acc['time'], df_acc['real'].astype(float), label='real')

# Adding title and labels
plt.title('rotation')
plt.xlabel('x')
plt.ylabel('y')

# Adding a legend
plt.legend()

# Show the plot
plt.show()

# %%
df_m0 = df_motor[df_motor['mid'] == 0]
df_m1 = df_motor[df_motor['mid'] == 1]
df_m2 = df_motor[df_motor['mid'] == 2]
df_m3 = df_motor[df_motor['mid'] == 3]

# %%
# Create the figure and the axes
plt.figure(figsize=(10, 6))

# Plotting the three different line graphs
plt.plot(df_m0['time'], df_m0['output'], label='m0 output')
plt.plot(df_m1['time'], df_m1['output'], label='m1 output')
plt.plot(df_m2['time'], df_m2['output'], label='m2 output')
plt.plot(df_m3['time'], df_m3['output'], label='m3 output')

#plt.plot(df_m0['time'], df_m0['angle'], label='m0 angle')
#plt.plot(df_m1['time'], df_m1['angle'], label='m1 angle')
#plt.plot(df_m2['time'], df_m2['angle'], label='m2 angle')

# Adding title and labels
plt.title('Motor Output')
plt.xlabel('x')
plt.ylabel('y')

# Adding a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
